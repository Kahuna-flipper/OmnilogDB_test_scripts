# %%
import numpy as np
import pandas as pd
from os import listdir
from os.path import isfile, join

# %%
path1 = '/home/kkrishnan/SBRG/OmnilogDB/Data/Irina-YTF/Metadata'
path2 = '/home/kkrishnan/SBRG/OmnilogDB/Data/Irina-YTF/Data'

onlyfiles = [f for f in listdir(path1) if isfile(join(path1, f))]

temp_data = pd.read_excel(path1+'/'+onlyfiles[0])
temp_data_2 = pd.read_excel(path1+'/'+onlyfiles[1])

metadata = pd.concat([temp_data,temp_data_2],ignore_index=True)

for i in range(2,len(onlyfiles)):
    temp_data = pd.read_excel(path1+'/'+onlyfiles[i])
    metadata = pd.concat([metadata,temp_data],ignore_index=True)

strains = metadata['Strain name'].unique().tolist()
species = metadata['Species'].unique().tolist()


plates = metadata['PM Type (PM1 or PM2, or PM3, or PM4...)']

for i in range(0,len(plates)):
    plates[i]=plates[i][0:2]+'0'+plates[i][2:]
    
metadata['PM Type (PM1 or PM2, or PM3, or PM4...)'] = plates

metadata
# Out:
# /tmp/ipykernel_1109172/3330124508.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plates[i]=plates[i][0:2]+'0'+plates[i][2:]
#     Number  Date (2022-02-23) Project name (SBRG or your own project)  \
# 0        1           20220510                                    SBRG
# 1        2           20220510                                    SBRG
# 2        3           20220510                                    SBRG
# 3        4           20220510                                    SBRG
# 4        5           20220510                                    SBRG
# ..     ...                ...                                     ...
# 79      40           20220517                                    SBRG
# 80      41           20220517                                    SBRG
# 81      42           20220517                                    SBRG
# 82      43           20220517                                    SBRG
# 83      44           20220517                                    SBRG
#
#                            Researcher  Species Strain name  \
# 0   Irina Rodionova, Jayanth Krishnan  E. coli     BW25113
# 1   Irina Rodionova, Jayanth Krishnan  E. coli     BW25113
# 2   Irina Rodionova, Jayanth Krishnan  E. coli     BW25113
# 3   Irina Rodionova, Jayanth Krishnan  E. coli     BW25113
# 4   Irina Rodionova, Jayanth Krishnan  E. coli        ybaO
# ..                                ...      ...         ...
# 79  Irina Rodionova, Jayanth Krishnan  E. coli        yidZ
# 80  Irina Rodionova, Jayanth Krishnan  E. coli        ynfL
# 81  Irina Rodionova, Jayanth Krishnan  E. coli        ynfL
# 82  Irina Rodionova, Jayanth Krishnan  E. coli        ynfL
# 83  Irina Rodionova, Jayanth Krishnan  E. coli        ynfL
#
#    WT or KO (if KO strain, please add the gene name)  \
# 0                                    Irina yTF genes
# 1                                    Irina yTF genes
# 2                                    Irina yTF genes
# 3                                    Irina yTF genes
# 4                                    Irina yTF genes
# ..                                               ...
# 79                                   Irina yTF genes
# 80                                   Irina yTF genes
# 81                                   Irina yTF genes
# 82                                   Irina yTF genes
# 83                                   Irina yTF genes
#
#                       Condition (Medium) Temp (37 or 30) Replicate (R1 or R2)  \
# 0   IF0a+Sodium Succinate/Ferric Citrate             37C                   R1
# 1   IF0a+Sodium Succinate/Ferric Citrate             37C                   R2
# 2   IF0a+Sodium Succinate/Ferric Citrate             37C                   R1
# 3   IF0a+Sodium Succinate/Ferric Citrate             37C                   R2
# 4   IF0a+Sodium Succinate/Ferric Citrate             37C                   R1
# ..                                   ...             ...                  ...
# 79                          M9 No Carbon             37C                   R2
# 80                          M9 No Carbon             37C                   R1
# 81                          M9 No Carbon             37C                   R2
# 82                          M9 No Carbon             37C                   R1
# 83                          M9 No Carbon             37C                   R2
#
#    PM Type (PM1 or PM2, or PM3, or PM4...)  \
# 0                                     PM05
# 1                                     PM05
# 2                                     PM07
# 3                                     PM07
# 4                                     PM05
# ..                                     ...
# 79                                    PM01
# 80                                    PM01
# 81                                    PM01
# 82                                    PM02
# 83                                    PM02
#
#    folder (AWS cloud folder if we transfer the data to AWS)  \
# 0                         biolog-db/SBRG/DATA_2022/05
# 1                         biolog-db/SBRG/DATA_2022/05
# 2                         biolog-db/SBRG/DATA_2022/05
# 3                         biolog-db/SBRG/DATA_2022/05
# 4                         biolog-db/SBRG/DATA_2022/05
# ..                                                ...
# 79                        biolog-db/SBRG/DATA_2022/05
# 80                        biolog-db/SBRG/DATA_2022/05
# 81                        biolog-db/SBRG/DATA_2022/05
# 82                        biolog-db/SBRG/DATA_2022/05
# 83                        biolog-db/SBRG/DATA_2022/05
#
#    Number of Omnilog Shelf
# 0                      24A
# 1                      24B
# 2                      23A
# 3                      23B
# 4                      22A
# ..                     ...
# 79                      5B
# 80                      4A
# 81                      4B
# 82                      3A
# 83                      3B
#
# [84 rows x 13 columns]

# %%
onlyfiles = [f for f in listdir(path2) if isfile(join(path2, f))]


for sheet_index in range(0,len(onlyfiles)):
    
    temp_data = pd.read_csv(path2+'/'+onlyfiles[sheet_index])

    temp_data.rename(columns={'Field 1': 'Strain', 'Field 2': 'Media','Field 3':'Specie','Field 4':'Replicate'}, inplace=True)

    for i in range(0,temp_data.shape[0]):

        replicate = temp_data.iloc[i]['Strain'][-2:]

        for st in strains:
            if st in temp_data.iloc[i]['Strain']:
                strain = st

        specie = metadata[metadata['Strain name']==strain]['Species'].unique().tolist()[0]
        sample = metadata[metadata['Strain name'] == strain]

        plate_type = temp_data.iloc[i]['Plate Type']
        sample_plates = sample['PM Type (PM1 or PM2, or PM3, or PM4...)']

        for pl in sample_plates:
            if pl in plate_type:
                media = sample['Condition (Medium)']

        temp_data.at[i,'Strain'] = strain
        temp_data.at[i,'Media'] = media
        temp_data.at[i,'Specie'] = specie
        temp_data.at[i,'Replicate'] = replicate
        
        temp_data.to_csv(onlyfiles[sheet_index], index=False)

# %%
onlyfiles
# Out:
# ['ybeF R2_E.Coli_E.Coli__7_37_SBR_709_5#10#2022_A_19B_29.csv',
#  'yidZ R1_E.Coli_E.Coli__5_37_SBR_709_5#10#2022_A_10A_10.csv',
#  'yiaG R2_E. coli_E. coli__1_37_SBR_709_5#17#2022_A_ 7B_9.csv',
#  'ynfL R2_E.Coli_E.Coli__7_37_SBR_709_5#10#2022_A_ 7B_5.csv',
#  'yidZ R1_E.Coli_E.Coli__7_37_SBR_709_5#10#2022_A_ 9A_8.csv',
#  'yiaG R1_E.Coli_E.Coli__7_37_SBR_709_5#10#2022_A_11A_12.csv',
#  'ynfL R2_E. coli_E. coli__1_37_SBR_709_5#17#2022_A_ 4B_3.csv',
#  'ynfL R1_E. coli_E. coli__2_37_SBR_709_5#17#2022_A_ 3A_0.csv',
#  'ybaO R1_E.Coli_E.Coli__5_37_SBR_709_5#10#2022_A_22A_34.csv',
#  'yeeY R1_E.Coli_E.Coli__7_37_SBR_709_5#10#2022_A_15A_7.csv',
#  'yahB R1_E. coli_E. coli__3_37_SBR_709_5#17#2022_A_23A_40.csv',
#  'ybaO R1_E.Coli_E.Coli__7_37_SBR_709_5#10#2022_A_21A_32.csv',
#  'BW25113 R2_E.Coli_E.Coli__5_37_SBR_709_5#10#2022_A_24B_39.csv',
#  'ycaN R2_E.Coli_E.Coli__5_37_SBR_709_5#10#2022_A_18B_27.csv',
#  'BW25113 R1_E. coli_E. coli__1_37_SBR_709_5#17#2022_A_13A_23.csv',
#  'ybeF R1_E.Coli_E.Coli__5_37_SBR_709_5#10#2022_A_20A_30.csv',
#  'yeeY R1_E. coli_E. coli__1_37_SBR_709_5#17#2022_A_ 8A_10.csv',
#  'ybaO R2_E. coli_E. coli__1_37_SBR_709_5#17#2022_A_10B_15.csv',
#  'ynf L R2_E. coli_E. coli__3_37_SBR_709_5#17#2022_A_15B_25.csv',
#  'ybeF R2_E.Coli_E.Coli__5_37_SBR_709_5#10#2022_A_20B_31.csv',
#  'yidZ R2_E.Coli_E.Coli__5_37_SBR_709_5#10#2022_A_10B_11.csv',
#  'yiaG R1_E. coli_E. coli__1_37_SBR_709_5#17#2022_A_ 7A_8.csv',
#  'ybeF R2_E. coli_E. coli__3_37_SBR_709_5#17#2022_A_21B_37.csv',
#  'yidZ R2_E.Coli_E.Coli__5_37_SBR_709_5#10#2022_A_ 9B_9.csv']

# %%
temp_data
# Out:
#                                             Plate File            Setup Time  \
# 0    F:\projects\DP_Clinical_strains\DP Clinical Is...  4/19/2022 2:31:30 PM
# 1    F:\projects\DP_Clinical_strains\DP Clinical Is...  4/19/2022 2:31:30 PM
# 2    F:\projects\DP_Clinical_strains\DP Clinical Is...  4/19/2022 2:31:30 PM
# 3    F:\projects\DP_Clinical_strains\DP Clinical Is...  4/19/2022 2:31:30 PM
# 4    F:\projects\DP_Clinical_strains\DP Clinical Is...  4/19/2022 2:31:30 PM
# ..                                                 ...                   ...
# 188  F:\projects\DP_Clinical_strains\DP Clinical Is...  4/19/2022 2:31:30 PM
# 189  F:\projects\DP_Clinical_strains\DP Clinical Is...  4/19/2022 2:31:30 PM
# 190  F:\projects\DP_Clinical_strains\DP Clinical Is...  4/19/2022 2:31:30 PM
# 191  F:\projects\DP_Clinical_strains\DP Clinical Is...  4/19/2022 2:31:30 PM
# 192  F:\projects\DP_Clinical_strains\DP Clinical Is...  4/19/2022 2:31:30 PM
#
#     Position Plate Type   Strain  \
# 0        5-A      PM04A  ELI 328
# 1        5-A      PM04A  ELI 328
# 2        5-A      PM04A  ELI 328
# 3        5-A      PM04A  ELI 328
# 4        5-A      PM04A  ELI 328
# ..       ...        ...      ...
# 188      5-A      PM04A  ELI 328
# 189      5-A      PM04A  ELI 328
# 190      5-A      PM04A  ELI 328
# 191      5-A      PM04A  ELI 328
# 192      5-A      PM04A  ELI 328
#
#                                                  Media   Specie Replicate  \
# 0    200    IF0a+Sodium Succinate/Ferric Citrate
# 20...  E. coli        R1
# 1    200    IF0a+Sodium Succinate/Ferric Citrate
# 20...  E. coli        R1
# 2    200    IF0a+Sodium Succinate/Ferric Citrate
# 20...  E. coli        R1
# 3    200    IF0a+Sodium Succinate/Ferric Citrate
# 20...  E. coli        R1
# 4    200    IF0a+Sodium Succinate/Ferric Citrate
# 20...  E. coli        R1
# ..                                                 ...      ...       ...
# 188  200    IF0a+Sodium Succinate/Ferric Citrate
# 20...  E. coli        R1
# 189  200    IF0a+Sodium Succinate/Ferric Citrate
# 20...  E. coli        R1
# 190  200    IF0a+Sodium Succinate/Ferric Citrate
# 20...  E. coli        R1
# 191  200    IF0a+Sodium Succinate/Ferric Citrate
# 20...  E. coli        R1
# 192  200    IF0a+Sodium Succinate/Ferric Citrate
# 20...  E. coli        R1
#
#       Hour      A01  ...       H03       H04       H05       H06       H07  \
# 0     0.00  11.0000  ...   11.0000   11.0000   11.0000   11.0000   11.0000
# 1     0.25  11.0000  ...   14.5800   11.0317   11.0000   12.9715   14.8762
# 2     0.50  11.0000  ...   14.8836   15.9122   13.7177   12.7604   11.0000
# 3     0.75  11.0000  ...   14.9198   11.0000   11.0000   11.0000   12.2386
# 4     1.00  11.1922  ...   16.4220   23.3161   16.7055   11.7519   12.7857
# ..     ...      ...  ...       ...       ...       ...       ...       ...
# 188  47.00  24.9381  ...  118.8610  100.3439  154.5224  257.4668  255.4211
# 189  47.25  34.7972  ...  118.0142   99.0153  154.9276  258.6726  256.8750
# 190  47.50  31.4302  ...  118.4934   99.9749  155.6640  255.5245  254.3816
# 191  47.75  32.0654  ...  119.6026   99.5311  161.1474  256.4414  252.6834
# 192  48.00  31.3890  ...  119.5815  104.3388  157.0839  256.6965  254.0658
#
#           H08       H09       H10      H11      H12
# 0     12.0904   11.0000   11.0000  14.4146  22.1918
# 1     11.0000   11.0000   20.3342  17.5041  21.9713
# 2     11.0000   11.0000   21.2532  22.2134  19.8993
# 3     11.0000   11.0000   25.0607  18.6027  19.2038
# 4     11.0000   11.0000   25.0222  17.3937  25.8237
# ..        ...       ...       ...      ...      ...
# 188   98.4627  259.6286  265.6455  80.6019  69.6174
# 189  100.9905  262.4843  268.2987  80.7955  63.4664
# 190  100.9312  259.8138  263.3963  81.0393  62.1794
# 191  102.3979  263.4268  267.6056  80.7727  64.2930
# 192  104.8777  263.2482  266.4602  82.9645  64.7914
#
# [193 rows x 105 columns]
